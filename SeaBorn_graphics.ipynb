# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # distplot ( )

# %%
e=pd.read_csv("50ülke.csv")

# %%
sns.distplot(e["BÜYÜME"])

# %%
n=pd.read_csv("dünyam.csv")
n.dropna(how="any",inplace=True)
n
# Out:
#      Sıralama                 Ülke         Nüfüs  Yıllık değişim oranı  \
# 0         1.0                China  1.415046e+09                  0.39
# 1         2.0                India  1.354052e+09                  1.11
# 2         3.0                 U.S.  3.267667e+08                  0.71
# 3         4.0            Indonesia  2.667950e+08                  1.06
# 4         5.0               Brazil  2.108680e+08                  0.75
# ..        ...                  ...           ...                   ...
# 196     197.0           Micronesia  1.062270e+05                  0.65
# 197     198.0                Aruba  1.056700e+04                  0.39
# 198     199.0  U.S. Virgin Islands  1.049140e+05                  0.01
# 199     200.0  Antigua and Barbuda  1.030500e+04                  1.02
# 200     201.0           Seychelles  9.523500e+04                  0.53
#
#      Yıllık değişim  Kişi/km2        km2    Göçmen  Doğum oranı  Ortalama yaş  \
# ...

# %%
sns.set(style="dark",palette="muted",font_scale=2)
sns.distplot(n["Doğum oranı"],bins=20,kde=False,color="y")
plt.tight_layout()
#layout ekrana sığdırmayı sağlıyor

# %%
sns.set(style="darkgrid",palette="muted",font_scale=1.5)
sns.distplot(n["Yıllık değişim oranı"],hist=False,rug=True,color="r")
plt.tight_layout()

# %%
sns.set(style="white",palette="Blues",font_scale=1.5)
sns.distplot(n["Ortalama yaş"],hist=False,color="g",kde_kws={"shade":True})
plt.tight_layout()

# %%
sns.set(style="whitegrid",palette="Blues",font_scale=1.5)
sns.distplot(n["Nüfüs"],color="m")
plt.tight_layout()

# %%
sns.set(style="darkgrid",font_scale=1.5)

f, axes = plt.subplots(2,2,figsize=(15,10))

sns.distplot(n["Doğum oranı"],bins=20,kde=False,color="y",ax=axes[0,0])

sns.distplot(n["Yıllık değişim oranı"],hist=False,rug=True,color="r",ax=axes[0,1])

sns.distplot(n["Ortalama yaş"],hist=False,color="g",kde_kws={"shade":True},ax=axes[1,0])

sns.distplot(n["Nüfüs"],color="m",ax=axes[1,1])

plt.tight_layout()

# %% [markdown]
# # jointplot ( )

# %%
sns.jointplot(n["Doğum oranı"],n["Ortalama yaş"],data=n)

# %%
sns.jointplot(n["Yıllık değişim oranı"],n["Doğum oranı"],data=n)

# %%
sns.jointplot(n["Yıllık değişim oranı"],n["Doğum oranı"],data=n,kind="hex",color="r")

# %%
sns.jointplot(n["Yıllık değişim oranı"],n["Doğum oranı"],data=n,kind="kde",xlim=(-2,6),ylim=(0,10),color="r",size=8)

# %% [markdown]
# # kdeplot ( )

# %%
e=pd.read_csv("50ülke.csv")
e.pop("2023")
e.pop("SIRALAMA")
e.pop("SIRALAMA.2")
e
# Out:
#                      ÜLKELER  MİLLİ GELİR  BÜYÜME  KİŞİ BAŞINA           KITA
# 0              United States     20412.87    2.27      62152.0  North America
# 1                      China     14092.51    6.86      10088.0           Asia
# 2                      Japan      5167.05    1.71      40849.0           Asia
# 3                    Germany      4211.64    2.51      50842.0         Europe
# 4             United Kingdom      2936.29    1.79      44177.0         Europe
# 5                     France      2925.10    1.85      44934.0         Europe
# 6                      India      2848.23    6.74       2135.0           Asia
# 7                      Italy      2181.97    1.47      35914.0         Europe
# 8                     Brazil      2138.92    0.98      10224.0  South America
# 9                     Canada      1798.51    3.00      48466.0  North America
# 10                    Russia      1719.90    1.55      11947.0         Europe
# ...

# %%
sns.kdeplot(e["KİŞİ BAŞINA"])

# %%
sns.kdeplot(e["BÜYÜME"])

# %%
sns.kdeplot(e["KİŞİ BAŞINA"],e["BÜYÜME"],shade=True,cmap="Reds")

# %%
sns.kdeplot(e["KİŞİ BAŞINA"],e["BÜYÜME"],shade=True,cmap="Blues")

# %% [markdown]
# # pairplot ( )

# %%
sns.pairplot(n,palette="#95a5a6")

# %%
sns.pairplot(e)

# %%
sns.pairplot(e,hue="KITA",palette="inferno")

# %% [markdown]
# # rugplot ()

# %%
sns.rugplot(e["BÜYÜME"],color="y",height=0.2)
sns.kdeplot(e["BÜYÜME"],color="r")

# %% [markdown]
# # boxplot ( )

# %%
sns.boxplot(x="KITA",y="KİŞİ BAŞINA",data=e,width=0.5)
plt.tight_layout()

# %%
sns.boxplot(x="KITA",y="BÜYÜME",data=e,palette="Set3")

# %%
ev=pd.read_csv("evli.csv")
ev
# Out:
#       isim  gelir     ay   evli
# 0      ali    100   ocak   evet
# 1    burak     80  şubat  hayır
# 2     veli    110   ocak   evet
# 3     fuat     45   mart  hayır
# 4    galip     60   mart   evet
# 5    davut     90  şubat   evet
# 6    tarık     80   ocak  hayır
# 7     emir     90  şubat   evet
# 8     umut    120   mart  hayır
# 9     ömer    130   mart   evet
# 10  ismail    100  şubat   evet
# 11   pınar    150   ocak  hayır
# 12   pelin    140   ocak  hayır
# 13    özge     40  şubat   evet
# 14    ışık     25  şubat  hayır
# 15    inci     76   mart   evet
# 16    faik    150  nisan   evet
# 17   ahmet     25  nisan   evet
# 18    elif     35  nisan  hayır
# 19    jale    200   mart  hayır
# 20   yeliz     46  ocak   hayır
# 21    tuna    120  şubat   evet
# 22   burak    140  şubat  hayır
# 23   selim    130  nisan  hayır
# 24    enes     90  nisan   evet

# %%
sns.boxplot(x="ay",y="gelir",data=ev,hue="evli",palette="PRGn")

# %% [markdown]
# # violinplot ( )

# %%
sns.violinplot(x="ay",y="gelir",data=ev,hue="evli",palette="PRGn",split=True,inner="points")

# %%
sns.set(style="whitegrid")
sns.violinplot(x="ay",y="gelir",data=ev,hue="evli",palette="PRGn",split=True,inner="points")

# %%
sns.set(style="whitegrid")
sns.violinplot(x="ay",y="gelir",data=ev,hue="evli",palette="PRGn")

# %%
sns.set(style="whitegrid")
sns.violinplot(x="KITA",y="BÜYÜME",data=e,palette="Set3",split=True)

# %% [markdown]
# # barplot ( )

# %%
sns.barplot(x="KITA",y="KİŞİ BAŞINA",data=e,palette="BuGn_d")

# %%
sns.barplot(x="KITA",y="KİŞİ BAŞINA",data=e,palette="RdBu_r")

# %%
sns.barplot(x="KITA",y="KİŞİ BAŞINA",data=e,palette="Set1")
sns.despine(left=True,bottom=True)

# %%
sns.barplot(x="KITA",y="KİŞİ BAŞINA",data=e,palette="Set1")

# %% [markdown]
# # countplot()

# %%
sns.countplot(x="KITA",data=e)

# %% [markdown]
# # stripplot ( )

# %%
sns.stripplot(x="KITA",y="BÜYÜME",data=e,color="red",jitter=True)

# %%
sns.stripplot(x="KITA",y="BÜYÜME",data=e,color="red")

# %%
sns.stripplot(x="KITA",y="BÜYÜME",data=e)

# %% [markdown]
# # swarmplot()

# %%
sns.swarmplot(x="KITA",y="BÜYÜME",data=e,color="red")

# %%
sns.violinplot(x="KITA",y="BÜYÜME",data=e)
sns.swarmplot(x="KITA",y="BÜYÜME",data=e,color="red")

# %% [markdown]
# # factorplot ( )

# %%
sns.factorplot(x="KITA",y="BÜYÜME",data=e,kind="bar")

# %%
sns.factorplot(x="KITA",y="BÜYÜME",data=e,kind="violin")

# %%
sns.factorplot(x="KİŞİ BAŞINA",y="BÜYÜME",data=e,kind="point")

# %%
t=pd.read_csv("titanic.csv")
t
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
sns.factorplot(x="Pclass",y="Survived",hue="Sex",size=6,data=t,kind="bar",palette="muted")

# %%
sns.factorplot(x="Pclass",y="Survived",hue="Sex",size=6,data=t,kind="violin",palette="muted")

# %% [markdown]
# # heatmap ( )

# %%
enf=pd.read_csv("tüfe.csv")
enfl=enf.pivot_table(index="ay",columns="yıl",values="enflasyon")
enfl
# Out:
# yıl       2008  2009   2010   2011   2012  2013  2014  2015  2016   2017
# ay
# aralık   10.06  6.53   6.40  10.45   6.16  7.40  8.17  8.81  8.53  11.92
# ağustos  11.77  5.33   8.33   6.65   8.88  8.17  9.54  7.14  8.79  10.68
# ekim     11.99  5.08   8.62   7.66   7.80  7.71  8.96  7.58  7.16  11.90
# eylül    11.13  5.27   9.24   6.15   9.19  7.88  8.86  7.95  7.28   7.29
# haziran  10.61  5.73   8.37   6.24   8.87  8.30  9.16  7.20  7.64  10.90
# kasım    10.76  5.53   7.29   9.48   6.37  7.32  9.15  8.10  7.00  12.98
# mart      9.15  7.89   9.56   3.99  10.43  7.29  8.39  7.61  7.46  11.29
# mayıs    10.74  5.24   9.10   7.17   8.28  6.51  9.66  8.09  6.58  11.72
# nisan     9.66  6.13  10.19   4.26  11.14  6.13  9.38  7.91  6.57  11.87
# ocak      8.17  9.50   8.19   4.90  10.61  7.31  7.75  7.24  9.58   9.22
# temmuz   12.06  5.39   7.58   6.31   9.07  8.88  9.32  6.81  8.05   9.79
# şubat     9.10  7.73  10.13   4.16  10.43  7.03  7.89  7.55  8.78  10.13

# %%
sns.heatmap(enfl)

# %%
sns.heatmap(enfl,annot=True)

# %%
sns.heatmap(enfl,annot=True,linecolor="black",lw=0.5)

# %% [markdown]
# # clustermap ( )

# %%
sns.clustermap(enfl,figsize=(6,6))

# %%
sns.clustermap(enfl,figsize=(13,13))

# %% [markdown]
# # lmplot ( )

# %%
sns.lmplot(x="KİŞİ BAŞINA",y="BÜYÜME",data=e)

# %%
sns.lmplot(x="BÜYÜME",y="KİŞİ BAŞINA",data=e,hue="KITA")

# %%
sns.lmplot(x="BÜYÜME",y="KİŞİ BAŞINA",data=e,col="KITA")

# %% [markdown]
# # PairGrid ( )

# %%
m=sns.PairGrid(n)
m.map_diag(sns.distplot)
m.map_upper(plt.scatter)
m.map_lower(sns.kdeplot)

# %%
k=sns.PairGrid(e)
k.map_diag(sns.distplot)
k.map_upper(plt.scatter)
k.map_lower(sns.kdeplot)

# %% [markdown]
# # FacetGrid

# %%
s=pd.read_csv("evli.csv")

# %%
ss=sns.FacetGrid(data=s,col="ay",row="evli")
ss.map(sns.distplot,"gelir")

# %%
ss=sns.FacetGrid(data=s,col="ay",row="evli")
ss.map(plt.hist,"gelir")
